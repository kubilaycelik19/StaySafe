# %%
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics 8.3.127  Python-3.10.16 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Setup complete  (12 CPUs, 13.9 GB RAM, 232.7/476.2 GB disk)

# %%
from ultralytics import YOLO
from IPython import display

# %%
# !yolo task=detect mode=train data="safetyDataset/data.yaml" model="yolo11m.pt" epochs=50 imgsz=640
# Out:
# ^C
# New https://pypi.org/project/ultralytics/8.3.131 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.127  Python-3.10.16 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
results= YOLO.train(
    data="safetyDataset/data.yaml", model="yolo11m.pt", epochs=50, imgsz=640, name="yolo11m_50e")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 YOLO.train(
#       2     data="safetyDataset/data.yaml", model="yolo11m.pt", epochs=50, imgsz=640)
#
# TypeError: Model.train() missing 1 required positional argument: 'self'
